# %%
# Welcome to Finance Starter Kit! Brought to you by the Logistic Regressions!

print(f'Enjoy reviewing our Secret Project Code Name: "FinWin"')
# Out:
# Enjoy reviewing our Secret Project Code Name: "FinWin"

# %%
# Introduction: Setting the Story

# This project is aimed to create a user-friendly financial solution 

# levering technology and machine learning to train Robo advisors to interact with new users, 

# searching for guidance on how to start their financial plan.

print(f'Lets gather some data now... shall we?') # Let's make it fun for the front-end user experience with messages like this!
# Out:
# Lets gather some data now... shall we?

# %%
# Fundational to Imports & Engines

import pandas as pd
import hvplot.pandas
from pathlib import Path
import os
import requests
import numpy as np
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi
import matplotlib.pyplot as plt
import datetime
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# Load .env environment to ensure all systems go!
load_dotenv()
# Out:
# <style>.bk-root, .bk-root .bk:before, .bk-root .bk:after {
#   font-family: var(--jp-ui-font-size1);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--jp-ui-font-color1);
# }
# </style>
# True

# %%
# Foundational Parameters 

def classify_age(age):
    if 18 <= age <= 30:
        return "Young"
    elif 31 <= age <= 50:
        return "Middle"
    elif 51 <= age <= 100:
        return "Old"
    else:
        return "Invalid"

# Dictionary to store newly created age classifications
age_class = {}

# Classify ages from 18 to 100 and store the results in the dictionary
for age in range(18, 101):
    classification = classify_age(age)
    age_class[age] = classification

# %%
# Proof of Concept on Age Groups

for age, classification in age_class.items():
    print(f"Age {age} belongs to the {classification} age group.")
# Out:
# Age 18 belongs to the Young age group.
# Age 19 belongs to the Young age group.
# Age 20 belongs to the Young age group.
# Age 21 belongs to the Young age group.
# Age 22 belongs to the Young age group.
# Age 23 belongs to the Young age group.
# Age 24 belongs to the Young age group.
# Age 25 belongs to the Young age group.
# Age 26 belongs to the Young age group.
# Age 27 belongs to the Young age group.
# Age 28 belongs to the Young age group.
# Age 29 belongs to the Young age group.
# Age 30 belongs to the Young age group.
# Age 31 belongs to the Middle age group.
# Age 32 belongs to the Middle age group.
# Age 33 belongs to the Middle age group.
# Age 34 belongs to the Middle age group.
# Age 35 belongs to the Middle age group.
# Age 36 belongs to the Middle age group.
# Age 37 belongs to the Middle age group.
# Age 38 belongs to the Middle age group.
# Age 39 belongs to the Middle age group.
# Age 40 belongs to the Middle age group.
# Age 41 belongs to the Middle age group.
# Age 42 belongs to the Middle age group.
# Age 43 belongs to the Middle age group.
# Age 44 belongs to the Middle age group.
# Age 45 belongs to the Middle age group.
# Age 46 belongs to the Middle age group.
# Age 47 belongs to the Middle age group.
# Age 48 belongs to the Middle age group.
# Age 49 belongs to the Middle age group.
# Age 50 belongs to the Middle age group.
# Age 51 belongs to the Old age group.
# Age 52 belongs to the Old age group.
# Age 53 belongs to the Old age group.
# Age 54 belongs to the Old age group.
# Age 55 belongs to the Old age group.
# Age 56 belongs to the Old age group.
# Age 57 belongs to the Old age group.
# Age 58 belongs to the Old age group.
# Age 59 belongs to the Old age group.
# Age 60 belongs to the Old age group.
# Age 61 belongs to the Old age group.
# Age 62 belongs to the Old age group.
# Age 63 belongs to the Old age group.
# Age 64 belongs to the Old age group.
# Age 65 belongs to the Old age group.
# Age 66 belongs to the Old age group.
# Age 67 belongs to the Old age group.
# Age 68 belongs to the Old age group.
# Age 69 belongs to the Old age group.
# Age 70 belongs to the Old age group.
# Age 71 belongs to the Old age group.
# Age 72 belongs to the Old age group.
# Age 73 belongs to the Old age group.
# Age 74 belongs to the Old age group.
# Age 75 belongs to the Old age group.
# Age 76 belongs to the Old age group.
# Age 77 belongs to the Old age group.
# Age 78 belongs to the Old age group.
# Age 79 belongs to the Old age group.
# Age 80 belongs to the Old age group.
# Age 81 belongs to the Old age group.
# Age 82 belongs to the Old age group.
# Age 83 belongs to the Old age group.
# Age 84 belongs to the Old age group.
# Age 85 belongs to the Old age group.
# Age 86 belongs to the Old age group.
# Age 87 belongs to the Old age group.
# Age 88 belongs to the Old age group.
# Age 89 belongs to the Old age group.
# Age 90 belongs to the Old age group.
# Age 91 belongs to the Old age group.
# Age 92 belongs to the Old age group.
# Age 93 belongs to the Old age group.
# Age 94 belongs to the Old age group.
# Age 95 belongs to the Old age group.
# Age 96 belongs to the Old age group.
# Age 97 belongs to the Old age group.
# Age 98 belongs to the Old age group.
# Age 99 belongs to the Old age group.
# Age 100 belongs to the Old age group.

# %%
core_solution = ['Bank', 'Invest', 'Home', 'Retire', 'Speculate']

# %%
start_money = list(range(0,10000001))

# %%
# Lets marry all these foundational parameters and 
data = {
    'Age_Group': classification,
    'Solution': core_solution,
    'Fav_Platform': ['Facebook', 'Instagram', 'Twitter', 'Reddit', 'Snapchat']
}

# Create a DataFrame from the sample dataset
df = pd.DataFrame(data)

# %%
# Let's see what we got here!

df
# Out:
#   Age_Group   Solution Fav_Platform
# 0       Old       Bank     Facebook
# 1       Old     Invest    Instagram
# 2       Old       Home      Twitter
# 3       Old     Retire       Reddit
# 4       Old  Speculate     Snapchat

# %%
# Setting the stage for next phase of Historical CSV Ingestion & Data Manipulation

yield_file = Path('./Resources/yield-rates-1990-2021.csv')

yield_csv = pd.read_csv(yield_file, index_col=[0], parse_dates=True, infer_datetime_format=True)

yield_csv
# Out:
#             1 Mo  2 Mo  3 Mo  4 Mo  6 Mo  1 Yr  2 Yr  3 Yr  5 Yr  7 Yr  10 Yr  \
# Date
# 2021-12-31  0.06  0.05  0.06   NaN  0.19  0.39  0.73  0.97  1.26  1.44   1.52
# 2021-12-30  0.06  0.06  0.05   NaN  0.19  0.38  0.73  0.98  1.27  1.44   1.52
# 2021-12-29  0.01  0.02  0.05   NaN  0.19  0.38  0.75  0.99  1.29  1.47   1.55
# 2021-12-28  0.03  0.04  0.06   NaN  0.20  0.39  0.74  0.99  1.27  1.41   1.49
# 2021-12-27  0.04  0.05  0.06   NaN  0.21  0.33  0.76  0.98  1.26  1.41   1.48
# ...          ...   ...   ...   ...   ...   ...   ...   ...   ...   ...    ...
# 1990-01-08   NaN   NaN  7.79   NaN  7.88  7.81  7.90  7.95  7.92  8.05   8.02
# 1990-01-05   NaN   NaN  7.79   NaN  7.85  7.79  7.90  7.94  7.92  8.03   7.99
# 1990-01-04   NaN   NaN  7.84   NaN  7.90  7.82  7.92  7.93  7.91  8.02   7.98
# 1990-01-03   NaN   NaN  7.89   NaN  7.94  7.85  7.94  7.96  7.92  8.04   7.99
# 1990-01-02   NaN   NaN  7.83   NaN  7.89  7.81  7.87  7.90  7.87  7.98   7.94
#
#             20 Yr  30 Yr
# Date
# 2021-12-31   1.94   1.90
# 2021-12-30   1.97   1.93
# 2021-12-29   2.00   1.96
# 2021-12-28   1.94   1.90
# 2021-12-27   1.92   1.88
# ...           ...    ...
# 1990-01-08    NaN   8.09
# 1990-01-05    NaN   8.06
# 1990-01-04    NaN   8.04
# 1990-01-03    NaN   8.04
# 1990-01-02    NaN   8.00
#
# [8008 rows x 13 columns]

# %%
fed_file = Path('./Resources/Fed_Reserve_Board.csv')

fed_csv = pd.read_csv(fed_file)

fed_csv
# Out:
#       Series Description Federal funds effective rate  \
# 0                  Unit:            Percent:_Per_Year
# 1            Multiplier:                            1
# 2              Currency:                          NaN
# 3    Unique Identifier:           H15/H15/RIFSPFF_N.M
# 4            Time Period                  RIFSPFF_N.M
# ..                   ...                          ...
# 276              2022-08                         2.33
# 277              2022-09                         2.56
# 278              2022-10                         3.08
# 279              2022-11                         3.78
# 280              2022-12                         4.10
#
#     30-Day AA Nonfinancial Commercial Paper Interest Rate  \
# 0                                              Percent
# 1                                                    1
# 2                                                  NaN
# 3                             H15/H15/RIFSPPNAAD30_N.M
# 4                                     RIFSPPNAAD30_N.M
# ..                                                 ...
# 276                                               2.33
# 277                                               2.80
# 278                                               3.28
# 279                                               3.88
# 280                                               4.20
#
#     60-Day AA Nonfinancial Commercial Paper Interest Rate  \
# 0                                              Percent
# 1                                                    1
# 2                                                  NaN
# 3                             H15/H15/RIFSPPNAAD60_N.M
# 4                                     RIFSPPNAAD60_N.M
# ..                                                 ...
# 276                                               2.46
# 277                                               2.91
# 278                                               3.50
# 279                                               4.03
# 280                                               4.31
#
#     90-Day AA Nonfinancial Commercial Paper Interest Rate  \
# 0                                              Percent
# 1                                                    1
# 2                                                  NaN
# 3                             H15/H15/RIFSPPNAAD90_N.M
# 4                                     RIFSPPNAAD90_N.M
# ..                                                 ...
# 276                                               2.57
# 277                                                 ND
# 278                                               3.81
# 279                                               4.25
# 280                                               4.45
#
#     30-Day AA Financial Commercial Paper Interest Rate  \
# 0                                              Percent
# 1                                                    1
# 2                                                  NaN
# 3                             H15/H15/RIFSPPFAAD30_N.M
# 4                                     RIFSPPFAAD30_N.M
# ..                                                 ...
# 276                                               2.38
# 277                                               2.79
# 278                                               3.32
# 279                                               3.90
# 280                                               4.21
#
#     60-Day AA Financial Commercial Paper Interest Rate  \
# 0                                              Percent
# 1                                                    1
# 2                                                  NaN
# 3                             H15/H15/RIFSPPFAAD60_N.M
# 4                                     RIFSPPFAAD60_N.M
# ..                                                 ...
# 276                                               2.53
# 277                                               3.33
# 278                                               3.45
# 279                                               4.10
# 280                                               4.37
#
#     90-Day AA Financial Commercial Paper Interest Rate  \
# 0                                              Percent
# 1                                                    1
# 2                                                  NaN
# 3                             H15/H15/RIFSPPFAAD90_N.M
# 4                                     RIFSPPFAAD90_N.M
# ..                                                 ...
# 276                                               2.76
# 277                                               3.21
# 278                                               3.85
# 279                                               4.46
# 280                                               4.51
#
#     Average majority prime rate charged by banks   on short-term loans to business,   quoted on an investment basis  \
# 0                                    Percent:_Per_Year
# 1                                                    1
# 2                                                  NaN
# 3                                 H15/H15/RIFSPBLP_N.M
# 4                                         RIFSPBLP_N.M
# ..                                                 ...
# 276                                               5.50
# 277                                               5.73
# 278                                               6.25
# 279                                               6.95
# 280                                               7.27
#
#     The rate charged for primary credit under   amendment to the Board's Regulation A  \
# 0                                    Percent:_Per_Year
# 1                                                    1
# 2                                                  NaN
# 3                               H15/H15/RIFSRP_F02_N.M
# 4                                       RIFSRP_F02_N.M
# ..                                                 ...
# 276                                               2.50
# 277                                               2.73
# 278                                               3.25
# 279                                               3.95
# 280                                               4.27
#
#      ...  \
# 0    ...
# 1    ...
# 2    ...
# 3    ...
# 4    ...
# ..   ...
# 276  ...
# 277  ...
# 278  ...
# 279  ...
# 280  ...
#
#     Market yield on U.S. Treasury securities at 7-year   constant maturity, quoted on investment basis  \
# 0                                    Percent:_Per_Year
# 1                                                    1
# 2                                                  NaN
# 3                               H15/H15/RIFLGFCY07_N.M
# 4                                       RIFLGFCY07_N.M
# ..                                                 ...
# 276                                               2.98
# 277                                               3.64
# 278                                               4.09
# 279                                               3.99
# 280                                               3.72
#
#     Market yield on U.S. Treasury securities at 10-year   constant maturity, quoted on investment basis  \
# 0                                    Percent:_Per_Year
# 1                                                    1
# 2                                                  NaN
# 3                               H15/H15/RIFLGFCY10_N.M
# 4                                       RIFLGFCY10_N.M
# ..                                                 ...
# 276                                               2.90
# 277                                               3.52
# 278                                               3.98
# 279                                               3.89
# 280                                               3.62
#
#     Market yield on U.S. Treasury securities at 20-year   constant maturity, quoted on investment basis  \
# 0                                    Percent:_Per_Year
# 1                                                    1
# 2                                                  NaN
# 3                               H15/H15/RIFLGFCY20_N.M
# 4                                       RIFLGFCY20_N.M
# ..                                                 ...
# 276                                               3.35
# 277                                               3.82
# 278                                               4.28
# 279                                               4.22
# 280                                               3.87
#
#     Market yield on U.S. Treasury securities at 30-year   constant maturity, quoted on investment basis  \
# 0                                    Percent:_Per_Year
# 1                                                    1
# 2                                                  NaN
# 3                               H15/H15/RIFLGFCY30_N.M
# 4                                       RIFLGFCY30_N.M
# ..                                                 ...
# 276                                               3.13
# 277                                               3.56
# 278                                               4.04
# 279                                               4.00
# 280                                               3.66
#
#     Market yield on U.S. Treasury securities at 5-year   constant maturity, quoted on investment basis,   inflation-indexed  \
# 0                                    Percent:_Per_Year
# 1                                                    1
# 2                                                  NaN
# 3                           H15/H15/RIFLGFCY05_XII_N.M
# 4                                   RIFLGFCY05_XII_N.M
# ..                                                 ...
# 276                                               0.34
# 277                                               1.25
# 278                                               1.71
# 279                                               1.61
# 280                                               1.45
#
#     Market yield on U.S. Treasury securities at 7-year   constant maturity, quoted on investment basis,   inflation-indexed  \
# 0                                    Percent:_Per_Year
# 1                                                    1
# 2                                                  NaN
# 3                           H15/H15/RIFLGFCY07_XII_N.M
# 4                                   RIFLGFCY07_XII_N.M
# ..                                                 ...
# 276                                               0.36
# 277                                               1.18
# 278                                               1.64
# 279                                               1.56
# 280                                               1.39
#
#     Market yield on U.S. Treasury securities at 10-year   constant maturity, quoted on investment basis,   inflation-indexed  \
# 0                                    Percent:_Per_Year
# 1                                                    1
# 2                                                  NaN
# 3                           H15/H15/RIFLGFCY10_XII_N.M
# 4                                   RIFLGFCY10_XII_N.M
# ..                                                 ...
# 276                                               0.39
# 277                                               1.14
# 278                                               1.59
# 279                                               1.52
# 280                                               1.36
#
#     Market yield on U.S. Treasury securities at 20-year   constant maturity, quoted on investment basis,   inflation-indexed  \
# 0                                    Percent:_Per_Year
# 1                                                    1
# 2                                                  NaN
# 3                           H15/H15/RIFLGFCY20_XII_N.M
# 4                                   RIFLGFCY20_XII_N.M
# ..                                                 ...
# 276                                               0.65
# 277                                               1.21
# 278                                               1.64
# 279                                               1.55
# 280                                               1.37
#
#     Market yield on U.S. Treasury securities at 30-year^  constant maturity, quoted on investment basis,^  inflation-indexed  \
# 0                                    Percent:_Per_Year
# 1                                                    1
# 2                                                  NaN
# 3                           H15/H15/RIFLGFCY30_XII_N.M
# 4                                   RIFLGFCY30_XII_N.M
# ..                                                 ...
# 276                                               0.84
# 277                                               1.29
# 278                                               1.71
# 279                                               1.60
# 280                                               1.40
#
#     Treasury long-term average (over 10 years)
# 0                            Percent:_Per_Year
# 1                                            1
# 2                                          NaN
# 3                      H15/H15/RIFLGFL_XII_N.M
# 4                              RIFLGFL_XII_N.M
# ..                                         ...
# 276                                       0.97
# 277                                       1.46
# 278                                       1.90
# 279                                       1.78
# 280                                       1.54
#
# [281 rows x 31 columns]

# %%
# Future Predictability Model

# We'll be using Prophet for this

from prophet import Prophet

# Prepare model and clean up data

new_df = yield_csv['1 Yr']

new_df = new_df.reset_index()

new_df = new_df.rename(columns={'Date': 'ds', '1 Yr': 'y'})

display(new_df)
# Out:
#              ds     y
# 0    2021-12-31  0.39
# 1    2021-12-30  0.38
# 2    2021-12-29  0.38
# 3    2021-12-28  0.39
# 4    2021-12-27  0.33
# ...         ...   ...
# 8003 1990-01-08  7.81
# 8004 1990-01-05  7.79
# 8005 1990-01-04  7.82
# 8006 1990-01-03  7.85
# 8007 1990-01-02  7.81
#
# [8008 rows x 2 columns]

# %%
# Model Creation

m = Prophet()
m.fit(new_df) # The New Df needs to be here. Working to convert Dates and Yields into ds and y

# Future 'indicators' Creation

future = m.make_future_dataframe(periods=365)
future.tail()
# Out:
# 19:37:03 - cmdstanpy - INFO - Chain [1] start processing
# 19:37:07 - cmdstanpy - INFO - Chain [1] done processing
#              ds
# 8368 2022-12-27
# 8369 2022-12-28
# 8370 2022-12-29
# 8371 2022-12-30
# 8372 2022-12-31

# %%
# Forecast model integrating newly 

forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#              ds      yhat  yhat_lower  yhat_upper
# 8368 2022-12-27  0.896381   -0.034956    1.752408
# 8369 2022-12-28  0.889349    0.041970    1.740385
# 8370 2022-12-29  0.885925   -0.020631    1.752967
# 8371 2022-12-30  0.882105    0.062810    1.750119
# 8372 2022-12-31  0.207854   -0.693233    1.021932

# %%
# Lets make this thing pretty! Visualization & Plots!

visual = m.plot(forecast)

# %%
## Placeholder for thoughts and ideas

# Determine what Technical Analysis / Trading Indicators can be .corr(related) with Minority Wealth
# Integrate Robo ChatBot with Lambda Jupyter Lab

# %%
inequality_csv = Path(pd.read_csv('./Resources/Income_Inequlity.csv'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 inequality_csv = Path(pd.read_csv('./Resources/Income_Inequlity.csv'))
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './Resources/Income_Inequlity.csv'
